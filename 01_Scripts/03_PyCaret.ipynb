# %% [markdown]
# # Imports

# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from pycaret.classification import *

from controller import Controller

# %%
c = Controller('i01')

cols_to_drop = [
    'PROJECT_ID',
    'TRAIN_VAL_TEST_SPLIT',
    'DEADLINE',
    'STATE_CHANGED_AT',
    'CREATED_AT',
    'LAUNCHED_AT',
    'KEYWORDS',
]

# %% [markdown]
# # Load data

# %%
filepath = fr'{c.get_path_data_prepared()}/01_df_development.pkl'
df_development = pd.read_pickle(filepath)
df_development = df_development.drop(cols_to_drop, axis=1)
df_development
# Out:
#                                                      NAME  \
# 0                                    Mall Of The Internet
# 1       The Don't Tell Darlings' New Album: """"""""""...
# 2                          OPEN SOURCE GAME Busters Nuts!
# 3                             Send SueNami - DRAG Olympic
# 4                                          Knowing Nile S
# ...                                                   ...
# 108124                                Somewhere Out There
# 108125                   Time Tracker Android Application
# 108126                                       Living Ruins
# 108127  iCulture Collection - fine poster prints, stic...
# 108128                     Fist Full of Zombies the Movie
#
#                                                      DESC     GOAL  \
# 0       First Virtual Reality Mall, eCommerce, Live Au...  60000.0
# 1       """"""""""""""""""""""""""""""""""""""""""""""...    800.0
# ...

# %% [markdown]
# # Run PyCaret

# %%
text_features = ['NAME', 'DESC']
df_development[text_features] = df_development[text_features].fillna('""')
s1 = setup(data=df_development, target='FINAL_STATUS', text_features=text_features)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_96767/1873141177.py in <cell line: 3>()
#       1 text_features = ['NAME', 'DESC', ]
#       2 df_development[text_features] = df_development[text_features].fillna('""')
# ----> 3 s1 = setup(data=df_development, target='FINAL_STATUS', text_features=text_features)
#
# ...

# %%
# compare baseline models
best = compare_models()

# %%
best
